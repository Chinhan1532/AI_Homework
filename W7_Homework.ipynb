# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinhan1532/AI_Homework/blob/main/W7_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Crabs

# %%
import pandas as pd
url = '/content/crabs.csv'
data = pd.read_csv(url)
data.head()
# Out:
#   speies sex  index  fontallip  rearwidth  length  width  depth
# 0      B   M      1        8.1        6.7    16.1   19.0    7.0
# 1      B   M      2        8.8        7.7    18.1   20.8    7.4
# 2      B   M      3        9.2        7.8    19.0   22.4    7.7
# 3      B   M      4        9.6        7.9    20.1   23.1    8.2
# 4      B   M      5        9.8        8.0    20.3   23.0    8.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#               index  fontallip  rearwidth    length     width     depth
# index      1.000000   0.862876   0.840040  0.911436  0.928248  0.864459
# fontallip  0.862876   1.000000   0.906988  0.978842  0.964956  0.987627
# rearwidth  0.840040   0.906988   1.000000  0.892743  0.900402  0.889205
# length     0.911436   0.978842   0.892743  1.000000  0.995023  0.983204
# width      0.928248   0.964956   0.900402  0.995023  1.000000  0.967812
# depth      0.864459   0.987627   0.889205  0.983204  0.967812  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation, annot = True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='fontallip',y='rearwidth',figsize=(9,9),color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='fontallip', ylabel='rearwidth'>

# %%
from sklearn import linear_model
model= linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['fontallip']), y=data['rearwidth'])
print('Giá trị Intercept là:',model.intercept_)
print('Giá trị Coeffient là:',model.coef_)

model.score(X=pd.DataFrame(data['fontallip']), y=data['rearwidth'])
# Out:
# Giá trị Intercept là: 2.3330227609573377
# Giá trị Coeffient là: [0.66774544]
# 0.8226265339436888

# %%
data.plot(kind='scatter',x='fontallip',y='rearwidth',figsize=(9,9),color='black')
y_pred=model.predict(X=pd.DataFrame(data['fontallip']))
plt.plot(data['fontallip'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['fontallip'], data['fontallip']**2]).T #Tranpose: chuyển vị
model.fit(X, y = data['rearwidth'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['rearwidth']))
# Out:
# Hệ số Intercept: -0.5298667863172515
# Hệ số Coeffient: [ 1.05402641 -0.01237921]
# Độ chính xác của mô hình: 0.8273475625599281

# %%
import numpy as np
range = np.arange(1.5, 20.5, 0.1)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'fontallip', y = 'rearwidth', figsize = (9,9), color = 'blue', xlim = (0,20))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['fontallip'], data['fontallip']**2, data['fontallip']**3, data['fontallip']**4, data['fontallip']**5]).T #Tranpose: chuyển vị
model.fit(X, y = data['rearwidth'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['rearwidth']))
# Out:
# Hệ số Intercept: 2.82618510971016
# Hệ số Coeffient: [-6.04035503e-01  2.64559689e-01 -2.06874866e-02  7.10259615e-04
#  -9.10735296e-06]
# Độ chính xác của mô hình: 0.8277744893266339

# %%
import numpy as np
range = np.arange(1.5, 20.5, 0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'fontallip', y = 'rearwidth', figsize = (9,9), color = 'blue', xlim = (0,20))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['fontallip'], data['fontallip']**2, data['fontallip']**3, data['fontallip']**4, data['fontallip']**5, data['fontallip']**6,
                  data['fontallip']**7, data['fontallip']**8, data['fontallip']**9, data['fontallip']**10]).T #Tranpose: chuyển vị
model.fit(X, y = data['rearwidth'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['rearwidth']))
# Out:
# Hệ số Intercept: 101.8736523970734
# Hệ số Coeffient: [-2.82200025e-01 -1.65990894e+00 -3.98450592e+00  1.62928992e+00
#  -2.81558967e-01  2.72093327e-02 -1.58314203e-03  5.52573075e-05
#  -1.06846929e-06  8.81402085e-09]
# Độ chính xác của mô hình: 0.831274128295308

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['fontallip'], data['fontallip']**2, data['fontallip']**3, data['fontallip']**4, data['fontallip']**5, data['fontallip']**6,
                  data['fontallip']**7, data['fontallip']**8]).T #Tranpose: chuyển vị
model.fit(X, y = data['rearwidth'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['rearwidth']))
# Out:
# Hệ số Intercept: 3073.27165078032
# Hệ số Coeffient: [-1.85246098e+03  4.77686899e+02 -6.88114419e+01  6.06626924e+00
#  -3.35501556e-01  1.13791990e-02 -2.16605656e-04  1.77331481e-06]
# Độ chính xác của mô hình: 0.8298539572776067

# %%
import numpy as np
range = np.arange(1.5, 20.5, 0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'fontallip', y = 'rearwidth', figsize = (9,9), color = 'blue', xlim = (0,20))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# # Social Network Ads

# %%
import pandas as pd
url=  '/content/Social_Network_Ads.csv'
data = pd.read_csv(url)
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.000721         0.071097   0.007120
# Age             -0.000721  1.000000         0.155238   0.622454
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083
# Purchased        0.007120  0.622454         0.362083   1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation, annot = True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='Age',y='Purchased',figsize=(9,9),color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Age', ylabel='Purchased'>

# %%
from sklearn import linear_model
model= linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['Age']), y=data['Purchased'])
print('Giá trị Intercept là:',model.intercept_)
print('Giá trị Coeffient là:',model.coef_)

model.score(X=pd.DataFrame(data['Age']), y=data['Purchased'])
# Out:
# Giá trị Intercept là: -0.7154209274697418
# Giá trị Coeffient là: [0.02849345]
# 0.387449229708981

# %%
data.plot(kind='scatter',x='Age',y='Purchased',figsize=(9,9),color='black')
y_pred=model.predict(X=pd.DataFrame(data['Age']))
plt.plot(data['Age'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Age'], data['Age']**2]).T #Tranpose: chuyển vị
model.fit(X, y = data['Purchased'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['Purchased']))
# Out:
# Hệ số Intercept: -0.10601582739866239
# Hệ số Coeffient: [-0.00535925  0.00043556]
# Độ chính xác của mô hình: 0.40052074482714484

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Age'], data['Age']**2, data['Age']**3, data['Age']**4, data['Age']**5, data['Age']**6, data['Age']**7, data['Age']**8
                  , data['Age']**9, data['Age']**10, data['Age']**11, data['Age']**12, data['Age']**13, data['Age']**14, data['Age']**15, data['Age']**16
                  , data['Age']**17, data['Age']**18, data['Age']**19, data['Age']**20, data['Age']**21, data['Age']**22, data['Age']**23, data['Age']**24]).T #Tranpose: chuyển vị
model.fit(X, y = data['Purchased'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['Purchased']))
# Out:
# Hệ số Intercept: 0.028779249174981147
# Hệ số Coeffient: [-2.88582945e-12  1.03383074e-09 -2.79762874e-09 -2.36798369e-08
#  -1.98629448e-07  3.66018793e-08 -2.21739014e-09  6.09643468e-11
#  -7.86163498e-13  3.86744846e-15 -4.74737324e-21 -1.09431381e-20
#   1.10858732e-21 -4.15652258e-21  2.71913320e-21 -4.16623856e-21
#   3.96879972e-21  6.32308492e-22  7.17723938e-21  1.80627811e-21
#   5.90317444e-21 -1.01329367e-20 -1.06688915e-20  1.10376913e-20]
# Độ chính xác của mô hình: 0.4668239050669061

# %%
import numpy as np
range = np.arange(1.5, 10.5, 0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10,range**11,range**12,range**13,range**14
                        ,range**15,range**16,range**17,range**18,range**19,range**20,range**21,range**22,range**23,range**24]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Age', y = 'Purchased', figsize = (9,9), color = 'blue', xlim = (0,10))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# #Google Stock Price Train

# %%
import pandas as pd
url='/content/abalone.csv'
data = pd.read_csv(url)
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data.hist()
plt.show()

# %%
correlation = data.corr()
print(correlation)
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# Shucked weight        0.931961      0.882617  0.420884
# Viscera weight        1.000000      0.907656  0.503819
# Shell weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(correlation, annot = True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='Diameter',y='Length',figsize=(9,9),color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Diameter', ylabel='Length'>

# %%
from sklearn import linear_model
model= linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['Diameter']), y=data['Length'])
print('Giá trị Intercept là:',model.intercept_)
print('Giá trị Coeffient là:',model.coef_)

model.score(X=pd.DataFrame(data['Diameter']), y=data['Length'])
# Out:
# Giá trị Intercept là: 0.03691333759877169
# Giá trị Coeffient là: [1.19416805]
# 0.9737971035056835

# %%
data.plot(kind='scatter',x='Diameter',y='Length',figsize=(9,9),color='black')
y_pred=model.predict(X=pd.DataFrame(data['Diameter']))
plt.plot(data['Diameter'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Diameter'], data['Diameter']**2, data['Diameter']**3]).T #Tranpose: chuyển vị
model.fit(X, y = data['Length'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['Length']))
# Out:
# Hệ số Intercept: 0.013692397599346928
# Hệ số Coeffient: [ 1.32468333 -0.1629934  -0.01629263]
# Độ chính xác của mô hình: 0.97414543880576

# %%
import numpy as np
range = np.arange(0, 2.5, 0.1)
X_range = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Diameter', y = 'Length', figsize = (9,9), color = 'blue', xlim = (0,1))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Diameter'], data['Diameter']**2, data['Diameter']**3, data['Diameter']**4, data['Diameter']**5, data['Diameter']**6, data['Diameter']**7, data['Diameter']**8, data['Diameter']**9, data['Diameter']**10]).T #Tranpose: chuyển vị
model.fit(X, y = data['Length'])
print('Hệ số Intercept:', model.intercept_)
print('Hệ số Coeffient:', model.coef_)
print('Độ chính xác của mô hình:', model.score(X, y = data['Length']))
# Out:
# Hệ số Intercept: -0.20820843765767427
# Hệ số Coeffient: [ 9.51373614e+00 -1.19829395e+02  8.79868559e+02 -3.29605925e+03
#   4.09139812e+03  1.45093910e+04 -7.11554038e+04  1.30403378e+05
#  -1.15906697e+05  4.13602459e+04]
# Độ chính xác của mô hình: 0.9742208082001076

# %%
import numpy as np
range = np.arange(0, 2, 0.1)
X_range = pd.DataFrame([range,range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X_range)
data.plot(kind = 'scatter', x = 'Diameter', y = 'Length', figsize = (9,9), color = 'blue', xlim = (0,0.8))
plt.plot(range, y_pred, color = 'red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
